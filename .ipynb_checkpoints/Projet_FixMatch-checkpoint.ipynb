# %% [markdown]
# # Quelques fournitures pour le projet d'apprentissage semi-supervisé

# %% [markdown]
# ## CIFAR-10
#
# Il vous est demandé pour ce projet d'utiliser les données de la base de données CIFAR-10, que vous pouvez récupérer avec les quelques lignes ci-dessous. Cette base de données est constituée des 10 classes suivantes :
#
#
# A vous de partager cette base en données labellisées et non labellisées en fonction des expériences que vous mènerez !

# %%
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# coucou

# %% [markdown]
# ## RandAugment
#
# Pour implémenter l'augmentation forte dans FixMatch, vous aurez besoin d'une politique d'augmentation de données apprise par renforcement. La méthode RandAugment a été implémentée dans la bibliothèque imgaug, voici comment l'utiliser

# %%
# !pip uninstall --yes imgaug
# !pip install imgaug==0.4.0
# Out:
# Found existing installation: imgaug 0.4.0
# Uninstalling imgaug-0.4.0:
#   Successfully uninstalled imgaug-0.4.0
# Collecting imgaug==0.4.0
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Requirement already satisfied: matplotlib in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (3.5.1)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (0.19.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (1.22.4)
# Requirement already satisfied: Shapely in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (2.0.1)
# Requirement already satisfied: scipy in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (1.7.3)
# Requirement already satisfied: opencv-python in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (4.7.0.72)
# Requirement already satisfied: imageio in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (2.9.0)
# Requirement already satisfied: six in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (1.16.0)
# Requirement already satisfied: Pillow in c:\users\yasmi\anaconda3\lib\site-packages (from imgaug==0.4.0) (9.0.1)
# Requirement already satisfied: networkx>=2.2 in c:\users\yasmi\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\yasmi\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\yasmi\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\yasmi\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2021.7.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\yasmi\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image>=0.14.2->imgaug==0.4.0) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yasmi\anaconda3\lib\site-packages (from matplotlib->imgaug==0.4.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yasmi\anaconda3\lib\site-packages (from matplotlib->imgaug==0.4.0) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yasmi\anaconda3\lib\site-packages (from matplotlib->imgaug==0.4.0) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\yasmi\anaconda3\lib\site-packages (from matplotlib->imgaug==0.4.0) (0.11.0)
# Installing collected packages: imgaug
# Successfully installed imgaug-0.4.0

# %%
import imgaug.augmenters as iaa
aug = iaa.RandAugment(n=2, m=9)

def randaugment(img):
  return aug(images=img)

# %%
import matplotlib.pyplot as plt

# Application de RandAugment aux 4 premières images de la base d'entraînement
aug_img = randaugment(x_train[0:4])

# Affichage des images originales (ligne du haut) et augmentées (ligne du bas)
for i in range(4):
  plt.subplot(2,4,i+1)
  plt.imshow(x_train[i])

  plt.subplot(2,4, i+5)
  plt.imshow(aug_img[i])

# %% [markdown]
# ## Réseau fourni
#
# Afin d'obtenir des résultats comparables, tout le monde devra utiliser le même réseau, que voici :

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', input_shape=(32,32,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(96, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dense(10,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 96)          55392
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         110720
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 453,290
# Trainable params: 453,290
# Non-trainable params: 0
# _________________________________________________________________
